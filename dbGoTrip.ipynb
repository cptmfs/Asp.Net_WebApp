-- %% [markdown]
-- # [dbGoTrip]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [dbGoTrip]    Script Date: 27.11.2023 08:34:56 ******/
CREATE DATABASE [dbGoTrip]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'dbGoTrip', FILENAME = N'C:\Users\mfsimsek\dbGoTrip.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'dbGoTrip_log', FILENAME = N'C:\Users\mfsimsek\dbGoTrip_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [dbGoTrip] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [dbGoTrip].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [dbGoTrip] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [dbGoTrip] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [dbGoTrip] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [dbGoTrip] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [dbGoTrip] SET ARITHABORT OFF 
GO
ALTER DATABASE [dbGoTrip] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [dbGoTrip] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [dbGoTrip] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [dbGoTrip] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [dbGoTrip] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [dbGoTrip] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [dbGoTrip] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [dbGoTrip] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [dbGoTrip] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [dbGoTrip] SET  DISABLE_BROKER 
GO
ALTER DATABASE [dbGoTrip] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [dbGoTrip] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [dbGoTrip] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [dbGoTrip] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [dbGoTrip] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [dbGoTrip] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [dbGoTrip] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [dbGoTrip] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [dbGoTrip] SET  MULTI_USER 
GO
ALTER DATABASE [dbGoTrip] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [dbGoTrip] SET DB_CHAINING OFF 
GO
ALTER DATABASE [dbGoTrip] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [dbGoTrip] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [dbGoTrip] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [dbGoTrip] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [dbGoTrip] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[tabloKurumsal]

-- %%
USE [dbGoTrip]
GO

-- %%
/****** Object:  Table [dbo].[tabloKurumsal]    Script Date: 27.11.2023 08:34:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tabloKurumsal](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Baslik] [nvarchar](50) NULL,
	[Ozet] [nvarchar](250) NULL,
	[Detay] [nvarchar](max) NULL,
 CONSTRAINT [PK_tabloKurumsal] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblAyarlar]

-- %%
/****** Object:  Table [dbo].[tblAyarlar]    Script Date: 27.11.2023 08:34:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblAyarlar](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Mail] [nvarchar](50) NULL,
	[Telefon] [nvarchar](50) NULL,
	[Adres] [nvarchar](max) NULL,
	[Youtube] [nvarchar](50) NULL,
	[Instagram] [nvarchar](50) NULL,
	[Facebook] [nvarchar](50) NULL,
	[Logo] [nvarchar](50) NULL,
	[SiteOzet] [nvarchar](max) NULL,
 CONSTRAINT [PK_tblAyarlar] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblBlog]

-- %%
/****** Object:  Table [dbo].[tblBlog]    Script Date: 27.11.2023 08:34:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblBlog](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Baslik] [nvarchar](50) NULL,
	[Ozet] [nvarchar](max) NULL,
	[KategoriId] [int] NULL,
	[Resim] [nvarchar](200) NULL,
	[Detay] [nvarchar](max) NULL,
	[Tarih] [datetime] NULL,
 CONSTRAINT [PK_tblBlog] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblBlogKategori]

-- %%
/****** Object:  Table [dbo].[tblBlogKategori]    Script Date: 27.11.2023 08:34:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblBlogKategori](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Ad] [nvarchar](50) NULL,
 CONSTRAINT [PK_tblBlogKategori] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblGaleri]

-- %%
/****** Object:  Table [dbo].[tblGaleri]    Script Date: 27.11.2023 08:34:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblGaleri](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Baslik] [nvarchar](100) NULL,
	[KategoriId] [int] NULL,
	[Resim] [nvarchar](100) NULL,
 CONSTRAINT [PK_tblGaleri] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblGaleriKategori]

-- %%
/****** Object:  Table [dbo].[tblGaleriKategori]    Script Date: 27.11.2023 08:34:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblGaleriKategori](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Adi] [nvarchar](50) NULL,
 CONSTRAINT [PK_tblGaleriKategori] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblTurPaket]

-- %%
/****** Object:  Table [dbo].[tblTurPaket]    Script Date: 27.11.2023 08:34:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblTurPaket](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Adi] [nvarchar](50) NULL,
	[Fiyat] [nvarchar](50) NULL,
	[Sure] [nvarchar](50) NULL,
	[Lokasyon] [nvarchar](200) NULL,
	[Resim] [nvarchar](200) NULL,
	[Detay] [nvarchar](max) NULL,
 CONSTRAINT [PK_tblKurumsal] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tabloKurumsal]

-- %%
SET IDENTITY_INSERT [dbo].[tabloKurumsal] ON 
INSERT [dbo].[tabloKurumsal] ([Id], [Baslik], [Ozet], [Detay]) VALUES (1, N'Hakkımızda', N'Hakkımızda Bilgiler', N'Şirket Hakkında Detaylı Bilgi Giriniz...<')
SET IDENTITY_INSERT [dbo].[tabloKurumsal] OFF
GO

-- %% [markdown]
-- # [dbo].[tblAyarlar]

-- %%
SET IDENTITY_INSERT [dbo].[tblAyarlar] ON 
INSERT [dbo].[tblAyarlar] ([Id], [Mail], [Telefon], [Adres], [Youtube], [Instagram], [Facebook], [Logo], [SiteOzet]) VALUES (23, N'cpt.mfs@gmail.com', N'536689999', N'Şehzadeler sok, ADa Cad. No  13', N'cptmfs', N'cptmfs', N'cptmfs', N'logo.jpg', N'siteozetasdsad')
SET IDENTITY_INSERT [dbo].[tblAyarlar] OFF
GO

-- %% [markdown]
-- # [dbo].[tblBlog]

-- %%
SET IDENTITY_INSERT [dbo].[tblBlog] ON 
INSERT [dbo].[tblBlog] ([Id], [Baslik], [Ozet], [KategoriId], [Resim], [Detay], [Tarih]) VALUES (1, N'Tur Rotalarımız', N'Tur Rotaları Hakkında Bilgiler içerir', 1, N'single_blog_2.png', N'Tur Rotaları Detayları Tur Rotaları Detayları Tur Rotaları Detayları Tur Rotaları Detayları Tur Rotaları Detayları Tur Rotaları Detayları Tur Rotaları Detayları Tur Rotaları Detayları Tur Rotaları Detayları ', CAST(N'2023-11-22T00:00:00.000' AS DateTime))
INSERT [dbo].[tblBlog] ([Id], [Baslik], [Ozet], [KategoriId], [Resim], [Detay], [Tarih]) VALUES (3, N'Kanada Tur Rotaları', N'Kanada Tur Rotaları Hakkında Bilgiler ', 1, N'single_blog_5.png', N'Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler Kanada Tur Rotaları Hakkında Bilgiler ', CAST(N'2023-11-23T08:55:21.000' AS DateTime))
INSERT [dbo].[tblBlog] ([Id], [Baslik], [Ozet], [KategoriId], [Resim], [Detay], [Tarih]) VALUES (1002, N'Avrupa Tur Rotası', N'Avrupadaki Tur rotaları ve gezilmesi gereken yerler açıklamada.', 1004, N'Venedik.png', N'Yolların büyüsü başkadır. Varılacak yerin önemini ortadan kaldırıp yaşanılan anı anlamlı ve özel kılar. Muhteşem bir seyahat deneyimidir. Kalabalık bir grupla yapıldığında verdiği his başkadır, iki kişilik olduğunda bambaşka. Yolculuğa çıkmadan önce özel çalma listeleri hazırlanır, yolda kaybolunur, sapaklar kaçırılır, molalarda farklı hislere kapılınır. Peki, özgürlük hissini bize yakınlaştıran yolları bambaşka rotalarla zenginleştirmeye ne dersin?

Road trip seviyorsan belki daha önce Türkiye’de denemişsindir. Peki, Avrupa’da farklı farklı yollarda keyifli bir yolculuğa kucak açmak kulağa nasıl geliyor? 

Eğer Avrupa’da en iyi road trip yapılacak yerleri merak ediyorsan senin için çeşitli öneriler hazırladık. Nefes kesici manzaraları barındıran bu rotalar içerisinden seç, beğen, yola çık! Tabii yurt dışında gerçekleştireceğin bir yolculuk olduğu için prosedürler biraz farklı olabilir. Bu sebeple önce bilmen gerekenlerden bahsedip sonrasında önerilerimize geçeceğiz. Ayrıca yurt dışına çıkmadan önce gideceğin ülkelerin güncel Covid-19 kurallarını ve vize şartlarını da kontrol etmelisin. Ucuz bileti nerede bulacağını zaten biliyorsun.', CAST(N'2023-11-24T10:08:41.000' AS DateTime))
SET IDENTITY_INSERT [dbo].[tblBlog] OFF
GO

-- %% [markdown]
-- # [dbo].[tblBlogKategori]

-- %%
SET IDENTITY_INSERT [dbo].[tblBlogKategori] ON 
INSERT [dbo].[tblBlogKategori] ([Id], [Ad]) VALUES (1, N'Gezi')
INSERT [dbo].[tblBlogKategori] ([Id], [Ad]) VALUES (2, N'Yeme İçme')
INSERT [dbo].[tblBlogKategori] ([Id], [Ad]) VALUES (1002, N'Seyehat')
INSERT [dbo].[tblBlogKategori] ([Id], [Ad]) VALUES (1003, N'Arkeolojik')
INSERT [dbo].[tblBlogKategori] ([Id], [Ad]) VALUES (1004, N'Avrupa')
SET IDENTITY_INSERT [dbo].[tblBlogKategori] OFF
GO

-- %% [markdown]
-- # [dbo].[tblGaleriKategori]

-- %%
SET IDENTITY_INSERT [dbo].[tblGaleriKategori] ON 
INSERT [dbo].[tblGaleriKategori] ([Id], [Adi]) VALUES (1, N'Doğa Resimleri')
INSERT [dbo].[tblGaleriKategori] ([Id], [Adi]) VALUES (2, N'Araç Resimleri')
INSERT [dbo].[tblGaleriKategori] ([Id], [Adi]) VALUES (3, N'Eğlence Mekanları')
INSERT [dbo].[tblGaleriKategori] ([Id], [Adi]) VALUES (4, N'Yeme/İçme')
SET IDENTITY_INSERT [dbo].[tblGaleriKategori] OFF
GO

-- %% [markdown]
-- # [dbo].[tblTurPaket]

-- %%
SET IDENTITY_INSERT [dbo].[tblTurPaket] ON 
INSERT [dbo].[tblTurPaket] ([Id], [Adi], [Fiyat], [Sure], [Lokasyon], [Resim], [Detay]) VALUES (1, N'Karadeniz Turu', N'14500', N'12', N'Karadeniz', N'services1.jpg', N'Trabzon,Rize, Artvin')
INSERT [dbo].[tblTurPaket] ([Id], [Adi], [Fiyat], [Sure], [Lokasyon], [Resim], [Detay]) VALUES (2, N'Uludağ Kayak Turu', N'8500', N'3', N'Türkiye,Bursa,Uludağ', N'services3.jpg', N'Uludağda Sınırsız Kayak Keyfi.')
INSERT [dbo].[tblTurPaket] ([Id], [Adi], [Fiyat], [Sure], [Lokasyon], [Resim], [Detay]) VALUES (1002, N'İstanbul Turu', N'7500', N'2', N'Turkey,Istanbul', N'', N'İstanbul tarihi yerler ve boğaz turu')
SET IDENTITY_INSERT [dbo].[tblTurPaket] OFF
GO

-- %% [markdown]
-- # [FK_tblBlog_tblBlogKategori]

-- %%
ALTER TABLE [dbo].[tblBlog]  WITH CHECK ADD  CONSTRAINT [FK_tblBlog_tblBlogKategori] FOREIGN KEY([KategoriId])
REFERENCES [dbo].[tblBlogKategori] ([Id])
GO
ALTER TABLE [dbo].[tblBlog] CHECK CONSTRAINT [FK_tblBlog_tblBlogKategori]
GO

-- %% [markdown]
-- # [FK_tblGaleri_tblGaleriKategori]

-- %%
ALTER TABLE [dbo].[tblGaleri]  WITH CHECK ADD  CONSTRAINT [FK_tblGaleri_tblGaleriKategori] FOREIGN KEY([KategoriId])
REFERENCES [dbo].[tblGaleriKategori] ([Id])
GO
ALTER TABLE [dbo].[tblGaleri] CHECK CONSTRAINT [FK_tblGaleri_tblGaleriKategori]
GO

-- %% [markdown]
-- # [dbGoTrip]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [dbGoTrip] SET  READ_WRITE 
GO
